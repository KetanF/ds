# %%
#2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('2.csv')

# %%
print(df.head())
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df.shape
# Out:
# (480, 17)

# %%
print(df['StageID'].isnull().head(10))
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: StageID, dtype: bool

# %%
print(df['StageID'].notnull().head(10))
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: StageID, dtype: bool

# %%
df.dropna(axis=0, how='any')
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
df.fillna(0,inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
plt.boxplot(x=df['raisedhands'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28abc625660>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x28abc625ba0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x28abc5cf1f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x28abc6260e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28abc626380>],
#  'means': []}

# %%
df.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
print('raisedhands')
# Out:
# raisedhands

# %%
df.to_string()
# Out:
# '    gender  NationalITy PlaceofBirth       StageID GradeID SectionID      Topic Semester Relation  raisedhands  VisITedResources  AnnouncementsView  Discussion ParentAnsweringSurvey ParentschoolSatisfaction StudentAbsenceDays Class\n0        M           KW       KuwaIT    lowerlevel    G-04         A         IT        F   Father           15                16                  2          20                   Yes                     Good            Under-7     M\n1        M           KW       KuwaIT    lowerlevel    G-04         A         IT        F   Father           20                20                  3          25                   Yes                     Good            Under-7     M\n2        M           KW       KuwaIT    lowerlevel    G-04         A         IT        F   Father           10                 7                  0          30                    No                      Bad            Above-7     L\n3        M           KW       KuwaIT    lowerlevel    G-04       
# ...

# %%
df.min()
# Out:
# gender                               F
# NationalITy                      Egypt
# PlaceofBirth                     Egypt
# StageID                     HighSchool
# GradeID                           G-02
# SectionID                            A
# Topic                           Arabic
# Semester                             F
# Relation                        Father
# raisedhands                          0
# VisITedResources                     0
# AnnouncementsView                    0
# Discussion                           1
# ParentAnsweringSurvey               No
# ParentschoolSatisfaction           Bad
# StudentAbsenceDays             Above-7
# Class                                H
# dtype: object

# %%
df.median()
# Out:
# C:\Users\Ketan\AppData\Local\Temp\ipykernel_25740\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# raisedhands          50.0
# VisITedResources     65.0
# AnnouncementsView    33.0
# Discussion           39.0
# dtype: float64

# %%
data_log=np.log(df['GradeID'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'str' object has no attribute 'log'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data_log=np.log(df['GradeID'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2113, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2109 @final
#    2110 def __array_ufunc__(
#    2111     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2112 ):
# -> 2113     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:402, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     399 elif self.ndim == 1:
#     400     # ufunc(series, ...)
# ...

# %%
fig,axs = plt.subplots(nrows=1,ncols=2)

axs[0].hist(df['GradeID'],edgecolor='red')
axs[1].hist(data_log,edgecolor='red')
axs[0].set_title("orgin")
axs[1].set_title("oafaf")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'str' object has no attribute 'log'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data_log=np.log(df['GradeID'])
#       2 fig,axs = plt.subplots(nrows=1,ncols=2)
#       4 axs[0].hist(df['GradeID'],edgecolor='red')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2113, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2109 @final
#    2110 def __array_ufunc__(
#    2111     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2112 ):
# -> 2113     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# ...
